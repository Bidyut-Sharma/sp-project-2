# %% [markdown]
# <a href="https://colab.research.google.com/github/Bidyut-Sharma/sp-project-2/blob/main/Matplot1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
#matplotlib exmple workflow
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#prepaare data
x=[6,7,8,9]
y=[66,77,88,99]
fig,ax=plt.subplots(figsize=(4,5))

#plot data
ax.plot(x,y)

# customise data
ax.set(title="simple plot",
       xlabel="x-axis",
       ylabel="y-axis")

#save figure
plt.savefig('Figures\sample.plot.png')

# %%
# !git clone https://github.com/Bidyut-Sharma/sp-project-2.git
# Out:
# Cloning into 'sp-project-2'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
